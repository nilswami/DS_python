# %%
df_dict = {'Year' : pd.Series([1990, 1994, 1998, 2002 , 2004]),
           'Country' : pd.Series(['Italy', 'USA', 'France', 'Japan']),
           'Winner' : pd.Series(['Germany', 'Brazil', 'France', 'Brazil']),
           'GoalScored' : pd.Series([115, 141, 171, 161])
          }

# %%
import pandas as pd

# %%
df = pd.DataFrame(df_dict)
df
# Out:
#    Year Country   Winner  GoalScored
# 0  1990   Italy  Germany       115.0
# 1  1994     USA   Brazil       141.0
# 2  1998  France   France       171.0
# 3  2002   Japan   Brazil       161.0
# 4  2004     NaN      NaN         NaN

# %%
df_lotuples = [(2002, 'Japan', 'Brazil', 161), 
                (2006, 'Germany', 'Italy', 147), 
                (2010, 'South Africa', 'Spain', 145),
                (2014, 'Brazil', 'Germany', 171)
              ]

# %%
df = pd.DataFrame(df_lotuples)
df
# Out:
#       0             1        2    3
# 0  2002         Japan   Brazil  161
# 1  2006       Germany    Italy  147
# 2  2010  South Africa    Spain  145
# 3  2014        Brazil  Germany  171

# %%
df = pd.DataFrame(df_lotuples, columns= ['year', 'country', 'country_2', 'goals scored'])
df
# Out:
#    year       country country_2  goals scored
# 0  2002         Japan    Brazil           161
# 1  2006       Germany     Italy           147
# 2  2010  South Africa     Spain           145
# 3  2014        Brazil   Germany           171

# %% [markdown]
# # Pandas basics

# %%
weather_data = pd.read_csv('datasets/weather_data.csv')
weather_data
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow
# 3  1/4/2017           24          7   Snow
# 4  1/5/2017           32          4   Rain
# 5  1/6/2017           31          2  Sunny

# %%
# Shape
weather_data.shape
# Out:
# (6, 4)

# %%
# Head() - displaying n data from the start
weather_data.head()
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow
# 3  1/4/2017           24          7   Snow
# 4  1/5/2017           32          4   Rain

# %%
weather_data.head(100)
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow
# 3  1/4/2017           24          7   Snow
# 4  1/5/2017           32          4   Rain
# 5  1/6/2017           31          2  Sunny

# %%
# Tail - displays the n data from the last, default is 5

# %%
weather_data.tail(2)
# Out:
#         day  temperature  windspeed  event
# 4  1/5/2017           32          4   Rain
# 5  1/6/2017           31          2  Sunny

# %%
# Info()
weather_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          6 non-null      object
#  1   temperature  6 non-null      int64
#  2   windspeed    6 non-null      int64
#  3   event        6 non-null      object
# dtypes: int64(2), object(2)
# memory usage: 320.0+ bytes

# %%
weather_data
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow
# 3  1/4/2017           24          7   Snow
# 4  1/5/2017           32          4   Rain
# 5  1/6/2017           31          2  Sunny

# %%
# basics of stats
weather_data.describe()
# Out:
#        temperature  windspeed
# count     6.000000   6.000000
# mean     30.333333   4.666667
# std       3.829708   2.338090
# min      24.000000   2.000000
# 25%      28.750000   2.500000
# 50%      31.500000   5.000000
# 75%      32.000000   6.750000
# max      35.000000   7.000000

# %%
weather_data
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow
# 3  1/4/2017           24          7   Snow
# 4  1/5/2017           32          4   Rain
# 5  1/6/2017           31          2  Sunny

# %%
weather_data.describe(include='all')
# Out:
#              day  temperature  windspeed event
# count          6     6.000000   6.000000     6
# unique         6          NaN        NaN     3
# top     1/1/2017          NaN        NaN  Rain
# freq           1          NaN        NaN     2
# mean         NaN    30.333333   4.666667   NaN
# std          NaN     3.829708   2.338090   NaN
# min          NaN    24.000000   2.000000   NaN
# 25%          NaN    28.750000   2.500000   NaN
# 50%          NaN    31.500000   5.000000   NaN
# 75%          NaN    32.000000   6.750000   NaN
# max          NaN    35.000000   7.000000   NaN

# %%
weather_data.describe(include= 'object')
# Out:
#              day event
# count          6     6
# unique         6     3
# top     1/1/2017  Rain
# freq           1     2

# %%
# Indexing and slicing

# %%
bike_share = pd.read_csv('datasets/citibike_tripdata.csv')
bike_share
# Out:
#        tripduration            starttime             stoptime  \
# 0               338  2018-05-01 00:04:47  2018-05-01 00:10:25
# 1              1482  2018-05-01 01:31:10  2018-05-01 01:55:53
# 2               232  2018-05-01 01:31:29  2018-05-01 01:35:22
# 3               190  2018-05-01 02:03:29  2018-05-01 02:06:40
# 4               303  2018-05-01 04:27:12  2018-05-01 04:32:16
# ...             ...                  ...                  ...
# 32423           396  2018-05-30 13:49:18  2018-05-30 13:55:55
# 32424           313  2018-05-30 13:49:21  2018-05-30 13:54:35
# 32425           316  2018-05-30 13:49:51  2018-05-30 13:55:08
# 32426          1130  2018-05-30 13:50:52  2018-05-30 14:09:42
# 32427           369  2018-05-30 13:50:58  2018-05-30 13:57:08
#
#        start station id   start station name  end station id end station name  \
# 0                  3639           Harborside            3199     Newport Pkwy
# ...

# %%
bike_share.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32428 entries, 0 to 32427
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   tripduration         32428 non-null  int64
#  1   starttime            32428 non-null  object
#  2   stoptime             32428 non-null  object
#  3   start station id     32428 non-null  int64
#  4   start station name   32428 non-null  object
#  5   end station id       32428 non-null  int64
#  6   end station name     32428 non-null  object
#  7   bikeid               32428 non-null  int64
#  8   name_localizedValue  32428 non-null  object
#  9   usertype             32428 non-null  object
# dtypes: int64(4), object(6)
# memory usage: 2.5+ MB

# %%
# Selecting a column

bike_share['starttime']
# Out:
# 0        2018-05-01 00:04:47
# 1        2018-05-01 01:31:10
# 2        2018-05-01 01:31:29
# 3        2018-05-01 02:03:29
# 4        2018-05-01 04:27:12
#                 ...
# 32423    2018-05-30 13:49:18
# 32424    2018-05-30 13:49:21
# 32425    2018-05-30 13:49:51
# 32426    2018-05-30 13:50:52
# 32427    2018-05-30 13:50:58
# Name: starttime, Length: 32428, dtype: object

# %%
print(type(bike_share['starttime']))
# Out:
# <class 'pandas.core.series.Series'>

# %%
# Selecting multiple column

bike_share[['starttime','stoptime']]
# Out:
#                  starttime             stoptime
# 0      2018-05-01 00:04:47  2018-05-01 00:10:25
# 1      2018-05-01 01:31:10  2018-05-01 01:55:53
# 2      2018-05-01 01:31:29  2018-05-01 01:35:22
# 3      2018-05-01 02:03:29  2018-05-01 02:06:40
# 4      2018-05-01 04:27:12  2018-05-01 04:32:16
# ...                    ...                  ...
# 32423  2018-05-30 13:49:18  2018-05-30 13:55:55
# 32424  2018-05-30 13:49:21  2018-05-30 13:54:35
# 32425  2018-05-30 13:49:51  2018-05-30 13:55:08
# 32426  2018-05-30 13:50:52  2018-05-30 14:09:42
# 32427  2018-05-30 13:50:58  2018-05-30 13:57:08
#
# [32428 rows x 2 columns]

# %%
bike_share.head(10)
# Out:
#    tripduration            starttime             stoptime  start station id  \
# 0           338  2018-05-01 00:04:47  2018-05-01 00:10:25              3639
# 1          1482  2018-05-01 01:31:10  2018-05-01 01:55:53              3681
# 2           232  2018-05-01 01:31:29  2018-05-01 01:35:22              3194
# 3           190  2018-05-01 02:03:29  2018-05-01 02:06:40              3185
# 4           303  2018-05-01 04:27:12  2018-05-01 04:32:16              3207
# 5           176  2018-05-01 04:37:05  2018-05-01 04:40:01              3194
# 6           577  2018-05-01 05:05:46  2018-05-01 05:15:23              3225
# 7           830  2018-05-01 05:11:50  2018-05-01 05:25:41              3207
# 8           395  2018-05-01 05:12:07  2018-05-01 05:18:42              3225
# 9           170  2018-05-01 05:13:52  2018-05-01 05:16:43              3206
#
#       start station name  end station id end station name  bikeid  \
# ...

# %%
bike_share.tail(10)
# Out:
#        tripduration            starttime             stoptime  \
# 32418           340  2018-05-30 13:42:45  2018-05-30 13:48:26
# 32419           307  2018-05-30 13:44:09  2018-05-30 13:49:16
# 32420           485  2018-05-30 13:44:46  2018-05-30 13:52:51
# 32421           255  2018-05-30 13:45:38  2018-05-30 13:49:54
# 32422           108  2018-05-30 13:49:12  2018-05-30 13:51:00
# 32423           396  2018-05-30 13:49:18  2018-05-30 13:55:55
# 32424           313  2018-05-30 13:49:21  2018-05-30 13:54:35
# 32425           316  2018-05-30 13:49:51  2018-05-30 13:55:08
# 32426          1130  2018-05-30 13:50:52  2018-05-30 14:09:42
# 32427           369  2018-05-30 13:50:58  2018-05-30 13:57:08
#
#        start station id   start station name  end station id end station name  \
# 32418              3203        Hamilton Park            3199     Newport Pkwy
# 32419              3187            Warren St            3202     Newport PATH
# ...

# %%
# Indexing

# %%
bike_share['starttime']
# Out:
# 0        2018-05-01 00:04:47
# 1        2018-05-01 01:31:10
# 2        2018-05-01 01:31:29
# 3        2018-05-01 02:03:29
# 4        2018-05-01 04:27:12
#                 ...
# 32423    2018-05-30 13:49:18
# 32424    2018-05-30 13:49:21
# 32425    2018-05-30 13:49:51
# 32426    2018-05-30 13:50:52
# 32427    2018-05-30 13:50:58
# Name: starttime, Length: 32428, dtype: object

# %%
df = bike_share['starttime'].head(10)

# %%
df
# Out:
# 0    2018-05-01 00:04:47
# 1    2018-05-01 01:31:10
# 2    2018-05-01 01:31:29
# 3    2018-05-01 02:03:29
# 4    2018-05-01 04:27:12
# 5    2018-05-01 04:37:05
# 6    2018-05-01 05:05:46
# 7    2018-05-01 05:11:50
# 8    2018-05-01 05:12:07
# 9    2018-05-01 05:13:52
# Name: starttime, dtype: object

# %%
df[4:9:2]
# Out:
# 4    2018-05-01 04:27:12
# 6    2018-05-01 05:05:46
# 8    2018-05-01 05:12:07
# Name: starttime, dtype: object

# %%
bike_share.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32428 entries, 0 to 32427
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   tripduration         32428 non-null  int64
#  1   starttime            32428 non-null  object
#  2   stoptime             32428 non-null  object
#  3   start station id     32428 non-null  int64
#  4   start station name   32428 non-null  object
#  5   end station id       32428 non-null  int64
#  6   end station name     32428 non-null  object
#  7   bikeid               32428 non-null  int64
#  8   name_localizedValue  32428 non-null  object
#  9   usertype             32428 non-null  object
# dtypes: int64(4), object(6)
# memory usage: 2.5+ MB

# %%
bike_share['bikeid'].head(20)
# Out:
# 0     33558
# 1     33593
# 2     29217
# 3     29662
# 4     15271
# 5     29298
# 6     33619
# 7     33624
# 8     26300
# 9     33555
# 10    33627
# 11    26216
# 12    33592
# 13    26160
# 14    33640
# 15    26190
# 16    29530
# 17    26163
# 18    29571
# 19    33634
# Name: bikeid, dtype: int64

# %%
bike_share
# Out:
#        tripduration            starttime             stoptime  \
# 0               338  2018-05-01 00:04:47  2018-05-01 00:10:25
# 1              1482  2018-05-01 01:31:10  2018-05-01 01:55:53
# 2               232  2018-05-01 01:31:29  2018-05-01 01:35:22
# 3               190  2018-05-01 02:03:29  2018-05-01 02:06:40
# 4               303  2018-05-01 04:27:12  2018-05-01 04:32:16
# ...             ...                  ...                  ...
# 32423           396  2018-05-30 13:49:18  2018-05-30 13:55:55
# 32424           313  2018-05-30 13:49:21  2018-05-30 13:54:35
# 32425           316  2018-05-30 13:49:51  2018-05-30 13:55:08
# 32426          1130  2018-05-30 13:50:52  2018-05-30 14:09:42
# 32427           369  2018-05-30 13:50:58  2018-05-30 13:57:08
#
#        start station id   start station name  end station id end station name  \
# 0                  3639           Harborside            3199     Newport Pkwy
# ...

# %%
# find the specific value
# df.at[rows , columns]
bike_share.at[2 , 'bikeid']
# Out:
# 29217

# %%
# Change the value ?
bike_share.at[2 , 'bikeid'] = 100

# %%
bike_share
# Out:
#        tripduration            starttime             stoptime  \
# 0               338  2018-05-01 00:04:47  2018-05-01 00:10:25
# 1              1482  2018-05-01 01:31:10  2018-05-01 01:55:53
# 2               232  2018-05-01 01:31:29  2018-05-01 01:35:22
# 3               190  2018-05-01 02:03:29  2018-05-01 02:06:40
# 4               303  2018-05-01 04:27:12  2018-05-01 04:32:16
# ...             ...                  ...                  ...
# 32423           396  2018-05-30 13:49:18  2018-05-30 13:55:55
# 32424           313  2018-05-30 13:49:21  2018-05-30 13:54:35
# 32425           316  2018-05-30 13:49:51  2018-05-30 13:55:08
# 32426          1130  2018-05-30 13:50:52  2018-05-30 14:09:42
# 32427           369  2018-05-30 13:50:58  2018-05-30 13:57:08
#
#        start station id   start station name  end station id end station name  \
# 0                  3639           Harborside            3199     Newport Pkwy
# ...

# %%
bike_share.at[32423 , 'end station id']
# Out:
# 3279

# %%
# Slicing

# %%
1. Normal slicing - It does the slicing only on rows
syntax 1
dataframe[start:stop:step]

syntax 2 
dataframe[row_name: row_end :step]

+ve and -ve slicing is possible

# %%
bike_share[10:20]
# Out:
#     tripduration            starttime             stoptime  start station id  \
# 10           353  2018-05-01 05:18:36  2018-05-01 05:24:29              3225
# 11           704  2018-05-01 05:23:26  2018-05-01 05:35:11              3185
# 12           265  2018-05-01 05:23:32  2018-05-01 05:27:58              3269
# 13           428  2018-05-01 05:31:40  2018-05-01 05:38:48              3212
# 14           473  2018-05-01 05:34:23  2018-05-01 05:42:16              3225
# 15           178  2018-05-01 05:34:30  2018-05-01 05:37:28              3267
# 16           309  2018-05-01 05:41:11  2018-05-01 05:46:21              3207
# 17           126  2018-05-01 05:53:34  2018-05-01 05:55:40              3214
# 18           184  2018-05-01 05:53:42  2018-05-01 05:56:46              3276
# 19           170  2018-05-01 05:53:43  2018-05-01 05:56:33              3267
#
#        start station name  end station id end station name  bikeid  \
# ...

# %%
bike_share[-1:-10:-1]
# Out:
#        tripduration            starttime             stoptime  \
# 32427           369  2018-05-30 13:50:58  2018-05-30 13:57:08
# 32426          1130  2018-05-30 13:50:52  2018-05-30 14:09:42
# 32425           316  2018-05-30 13:49:51  2018-05-30 13:55:08
# 32424           313  2018-05-30 13:49:21  2018-05-30 13:54:35
# 32423           396  2018-05-30 13:49:18  2018-05-30 13:55:55
# 32422           108  2018-05-30 13:49:12  2018-05-30 13:51:00
# 32421           255  2018-05-30 13:45:38  2018-05-30 13:49:54
# 32420           485  2018-05-30 13:44:46  2018-05-30 13:52:51
# 32419           307  2018-05-30 13:44:09  2018-05-30 13:49:16
#
#        start station id   start station name  end station id end station name  \
# 32427              3220    5 Corners Library            3207      Oakland Ave
# 32426              3281  Leonard Gordon Park            3213   Van Vorst Park
# 32425              3220    5 Corners Library            3195          Sip Ave
# ...

# %%
bike_share[0:10:3] #0, 3,6,9
# Out:
#    tripduration            starttime             stoptime  start station id  \
# 0           338  2018-05-01 00:04:47  2018-05-01 00:10:25              3639
# 3           190  2018-05-01 02:03:29  2018-05-01 02:06:40              3185
# 6           577  2018-05-01 05:05:46  2018-05-01 05:15:23              3225
# 9           170  2018-05-01 05:13:52  2018-05-01 05:16:43              3206
#
#       start station name  end station id end station name  bikeid  \
# 0             Harborside            3199     Newport Pkwy   33558
# 3              City Hall            3186    Grove St PATH   29662
# 6  Baldwin at Montgomery            3186    Grove St PATH   33619
# 9                Hilltop            3195          Sip Ave   33555
#
#                     name_localizedValue    usertype
# 0                     Annual Membership  Subscriber
# 3                               24 Hour    Customer
# 6  Annual Membership from Citi Bike App  Subscriber
# ...

# %%
bike_share[-9:-1]
# Out:
#        tripduration            starttime             stoptime  \
# 32419           307  2018-05-30 13:44:09  2018-05-30 13:49:16
# 32420           485  2018-05-30 13:44:46  2018-05-30 13:52:51
# 32421           255  2018-05-30 13:45:38  2018-05-30 13:49:54
# 32422           108  2018-05-30 13:49:12  2018-05-30 13:51:00
# 32423           396  2018-05-30 13:49:18  2018-05-30 13:55:55
# 32424           313  2018-05-30 13:49:21  2018-05-30 13:54:35
# 32425           316  2018-05-30 13:49:51  2018-05-30 13:55:08
# 32426          1130  2018-05-30 13:50:52  2018-05-30 14:09:42
#
#        start station id   start station name  end station id end station name  \
# 32419              3187            Warren St            3202     Newport PATH
# 32420              3183       Exchange Place            3211       Newark Ave
# 32421              3183       Exchange Place            3213   Van Vorst Park
# 32422              3202         Newport PATH            3199     Newport Pkwy
# ...

# %%
new_bike_share_data = bike_share[0:6]
new_bike_share_data
# Out:
#    tripduration            starttime             stoptime  start station id  \
# 0           338  2018-05-01 00:04:47  2018-05-01 00:10:25              3639
# 1          1482  2018-05-01 01:31:10  2018-05-01 01:55:53              3681
# 2           232  2018-05-01 01:31:29  2018-05-01 01:35:22              3194
# 3           190  2018-05-01 02:03:29  2018-05-01 02:06:40              3185
# 4           303  2018-05-01 04:27:12  2018-05-01 04:32:16              3207
# 5           176  2018-05-01 04:37:05  2018-05-01 04:40:01              3194
#
#   start station name  end station id end station name  bikeid  \
# 0         Harborside            3199     Newport Pkwy   33558
# 1           Grand St            3185        City Hall   33593
# 2    McGinley Square            3193     Lincoln Park     100
# 3          City Hall            3186    Grove St PATH   29662
# 4        Oakland Ave            3195          Sip Ave   15271
# ...

# %%
indx = ['row1','row2','row3','row4','row5','row6']
new_bike_share_data
# Out:
#    tripduration            starttime             stoptime  start station id  \
# 0           338  2018-05-01 00:04:47  2018-05-01 00:10:25              3639
# 1          1482  2018-05-01 01:31:10  2018-05-01 01:55:53              3681
# 2           232  2018-05-01 01:31:29  2018-05-01 01:35:22              3194
# 3           190  2018-05-01 02:03:29  2018-05-01 02:06:40              3185
# 4           303  2018-05-01 04:27:12  2018-05-01 04:32:16              3207
# 5           176  2018-05-01 04:37:05  2018-05-01 04:40:01              3194
#
#   start station name  end station id end station name  bikeid  \
# 0         Harborside            3199     Newport Pkwy   33558
# 1           Grand St            3185        City Hall   33593
# 2    McGinley Square            3193     Lincoln Park     100
# 3          City Hall            3186    Grove St PATH   29662
# 4        Oakland Ave            3195          Sip Ave   15271
# ...

# %%
new_bike_share_data.index = indx

# %%
new_bike_share_data
# Out:
#       tripduration            starttime             stoptime  \
# row1           338  2018-05-01 00:04:47  2018-05-01 00:10:25
# row2          1482  2018-05-01 01:31:10  2018-05-01 01:55:53
# row3           232  2018-05-01 01:31:29  2018-05-01 01:35:22
# row4           190  2018-05-01 02:03:29  2018-05-01 02:06:40
# row5           303  2018-05-01 04:27:12  2018-05-01 04:32:16
# row6           176  2018-05-01 04:37:05  2018-05-01 04:40:01
#
#       start station id start station name  end station id end station name  \
# row1              3639         Harborside            3199     Newport Pkwy
# row2              3681           Grand St            3185        City Hall
# row3              3194    McGinley Square            3193     Lincoln Park
# row4              3185          City Hall            3186    Grove St PATH
# row5              3207        Oakland Ave            3195          Sip Ave
# row6              3194    McGinley Square            3195          Sip Ave
#
# ...

# %%
# row2,row4,row6
new_bike_share_data['row2'::2]
# Out:
#       tripduration            starttime             stoptime  \
# row2          1482  2018-05-01 01:31:10  2018-05-01 01:55:53
# row4           190  2018-05-01 02:03:29  2018-05-01 02:06:40
# row6           176  2018-05-01 04:37:05  2018-05-01 04:40:01
#
#       start station id start station name  end station id end station name  \
# row2              3681           Grand St            3185        City Hall
# row4              3185          City Hall            3186    Grove St PATH
# row6              3194    McGinley Square            3195          Sip Ave
#
#       bikeid name_localizedValue    usertype
# row2   33593             24 Hour    Customer
# row4   29662             24 Hour    Customer
# row6   29298   Annual Membership  Subscriber

# %%
new_bike_share_data['row1':'row3']
# Out:
#       tripduration            starttime             stoptime  \
# row1           338  2018-05-01 00:04:47  2018-05-01 00:10:25
# row2          1482  2018-05-01 01:31:10  2018-05-01 01:55:53
# row3           232  2018-05-01 01:31:29  2018-05-01 01:35:22
#
#       start station id start station name  end station id end station name  \
# row1              3639         Harborside            3199     Newport Pkwy
# row2              3681           Grand St            3185        City Hall
# row3              3194    McGinley Square            3193     Lincoln Park
#
#       bikeid                      name_localizedValue    usertype
# row1   33558                        Annual Membership  Subscriber
# row2   33593                                  24 Hour    Customer
# row3     100  FREE Bonus Month with Annual Membership  Subscriber

# %%
# loc method 
- does the slicing on rows and columns
synbtax - daframe.loc[row_start_name : row_end :step , column_start:column_stop:step]

# %%
new_bike_share_data.loc['row1':'row3']
# Out:
#       tripduration            starttime             stoptime  \
# row1           338  2018-05-01 00:04:47  2018-05-01 00:10:25
# row2          1482  2018-05-01 01:31:10  2018-05-01 01:55:53
# row3           232  2018-05-01 01:31:29  2018-05-01 01:35:22
#
#       start station id start station name  end station id end station name  \
# row1              3639         Harborside            3199     Newport Pkwy
# row2              3681           Grand St            3185        City Hall
# row3              3194    McGinley Square            3193     Lincoln Park
#
#       bikeid                      name_localizedValue    usertype
# row1   33558                        Annual Membership  Subscriber
# row2   33593                                  24 Hour    Customer
# row3     100  FREE Bonus Month with Annual Membership  Subscriber

# %%
bike_share
# Out:
#        tripduration            starttime             stoptime  \
# 0               338  2018-05-01 00:04:47  2018-05-01 00:10:25
# 1              1482  2018-05-01 01:31:10  2018-05-01 01:55:53
# 2               232  2018-05-01 01:31:29  2018-05-01 01:35:22
# 3               190  2018-05-01 02:03:29  2018-05-01 02:06:40
# 4               303  2018-05-01 04:27:12  2018-05-01 04:32:16
# ...             ...                  ...                  ...
# 32423           396  2018-05-30 13:49:18  2018-05-30 13:55:55
# 32424           313  2018-05-30 13:49:21  2018-05-30 13:54:35
# 32425           316  2018-05-30 13:49:51  2018-05-30 13:55:08
# 32426          1130  2018-05-30 13:50:52  2018-05-30 14:09:42
# 32427           369  2018-05-30 13:50:58  2018-05-30 13:57:08
#
#        start station id   start station name  end station id end station name  \
# 0                  3639           Harborside            3199     Newport Pkwy
# ...

# %%
bike_share.loc[:10:4]
# Out:
#    tripduration            starttime             stoptime  start station id  \
# 0           338  2018-05-01 00:04:47  2018-05-01 00:10:25              3639
# 4           303  2018-05-01 04:27:12  2018-05-01 04:32:16              3207
# 8           395  2018-05-01 05:12:07  2018-05-01 05:18:42              3225
#
#       start station name  end station id end station name  bikeid  \
# 0             Harborside            3199     Newport Pkwy   33558
# 4            Oakland Ave            3195          Sip Ave   15271
# 8  Baldwin at Montgomery            3186    Grove St PATH   26300
#
#   name_localizedValue    usertype
# 0   Annual Membership  Subscriber
# 4   Annual Membership  Subscriber
# 8   Annual Membership  Subscriber

# %%
new_bike_share_data.loc[['row1','row3','row6'] , ['tripduration', 'bikeid']]

# 'row1','row3','row6'
# ['tripduration', 'bikeid']
# Out:
#       tripduration  bikeid
# row1           338   33558
# row3           232     100
# row6           176   29298

# %%
# extract

# %%
new_bike_share_data
# Out:
#       tripduration            starttime             stoptime  \
# row1           338  2018-05-01 00:04:47  2018-05-01 00:10:25
# row2          1482  2018-05-01 01:31:10  2018-05-01 01:55:53
# row3           232  2018-05-01 01:31:29  2018-05-01 01:35:22
# row4           190  2018-05-01 02:03:29  2018-05-01 02:06:40
# row5           303  2018-05-01 04:27:12  2018-05-01 04:32:16
# row6           176  2018-05-01 04:37:05  2018-05-01 04:40:01
#
#       start station id start station name  end station id end station name  \
# row1              3639         Harborside            3199     Newport Pkwy
# row2              3681           Grand St            3185        City Hall
# row3              3194    McGinley Square            3193     Lincoln Park
# row4              3185          City Hall            3186    Grove St PATH
# row5              3207        Oakland Ave            3195          Sip Ave
# row6              3194    McGinley Square            3195          Sip Ave
#
# ...

# %%
new_bike_share_data[new_bike_share_data['tripduration']<300]
# Out:
#       tripduration            starttime             stoptime  \
# row3           232  2018-05-01 01:31:29  2018-05-01 01:35:22
# row4           190  2018-05-01 02:03:29  2018-05-01 02:06:40
# row6           176  2018-05-01 04:37:05  2018-05-01 04:40:01
#
#       start station id start station name  end station id end station name  \
# row3              3194    McGinley Square            3193     Lincoln Park
# row4              3185          City Hall            3186    Grove St PATH
# row6              3194    McGinley Square            3195          Sip Ave
#
#       bikeid                      name_localizedValue    usertype
# row3     100  FREE Bonus Month with Annual Membership  Subscriber
# row4   29662                                  24 Hour    Customer
# row6   29298                        Annual Membership  Subscriber

# %%
new_bike_share_data.loc['row4':: , ::2]
# Out:
#       tripduration             stoptime start station name end station name  \
# row4           190  2018-05-01 02:06:40          City Hall    Grove St PATH
# row5           303  2018-05-01 04:32:16        Oakland Ave          Sip Ave
# row6           176  2018-05-01 04:40:01    McGinley Square          Sip Ave
#
#      name_localizedValue
# row4             24 Hour
# row5   Annual Membership
# row6   Annual Membership

# %%
new_bike_share_data.loc[:: , 'tripduration':'name_localizedValue']
# Out:
#       tripduration            starttime             stoptime  \
# row1           338  2018-05-01 00:04:47  2018-05-01 00:10:25
# row2          1482  2018-05-01 01:31:10  2018-05-01 01:55:53
# row3           232  2018-05-01 01:31:29  2018-05-01 01:35:22
# row4           190  2018-05-01 02:03:29  2018-05-01 02:06:40
# row5           303  2018-05-01 04:27:12  2018-05-01 04:32:16
# row6           176  2018-05-01 04:37:05  2018-05-01 04:40:01
#
#       start station id start station name  end station id end station name  \
# row1              3639         Harborside            3199     Newport Pkwy
# row2              3681           Grand St            3185        City Hall
# row3              3194    McGinley Square            3193     Lincoln Park
# row4              3185          City Hall            3186    Grove St PATH
# row5              3207        Oakland Ave            3195          Sip Ave
# row6              3194    McGinley Square            3195          Sip Ave
#
# ...

# %%
new_bike_share_data.loc[::-1 , ::-1]
# Out:
#         usertype                      name_localizedValue  bikeid  \
# row6  Subscriber                        Annual Membership   29298
# row5  Subscriber                        Annual Membership   15271
# row4    Customer                                  24 Hour   29662
# row3  Subscriber  FREE Bonus Month with Annual Membership     100
# row2    Customer                                  24 Hour   33593
# row1  Subscriber                        Annual Membership   33558
#
#      end station name  end station id start station name  start station id  \
# row6          Sip Ave            3195    McGinley Square              3194
# row5          Sip Ave            3195        Oakland Ave              3207
# row4    Grove St PATH            3186          City Hall              3185
# row3     Lincoln Park            3193    McGinley Square              3194
# row2        City Hall            3185           Grand St              3681
# ...

# %%
new_bike_share_data
# Out:
#       tripduration            starttime             stoptime  \
# row1           338  2018-05-01 00:04:47  2018-05-01 00:10:25
# row2          1482  2018-05-01 01:31:10  2018-05-01 01:55:53
# row3           232  2018-05-01 01:31:29  2018-05-01 01:35:22
# row4           190  2018-05-01 02:03:29  2018-05-01 02:06:40
# row5           303  2018-05-01 04:27:12  2018-05-01 04:32:16
# row6           176  2018-05-01 04:37:05  2018-05-01 04:40:01
#
#       start station id start station name  end station id end station name  \
# row1              3639         Harborside            3199     Newport Pkwy
# row2              3681           Grand St            3185        City Hall
# row3              3194    McGinley Square            3193     Lincoln Park
# row4              3185          City Hall            3186    Grove St PATH
# row5              3207        Oakland Ave            3195          Sip Ave
# row6              3194    McGinley Square            3195          Sip Ave
#
# ...

# %%
# Get only those data where user type is Subscriber and the bikeid >30000

# %%
new_bike_share_data.loc[(new_bike_share_data['usertype'] == 'Subscriber') & (new_bike_share_data['bikeid']< 30000) ]
# Out:
#       tripduration            starttime             stoptime  \
# row3           232  2018-05-01 01:31:29  2018-05-01 01:35:22
# row5           303  2018-05-01 04:27:12  2018-05-01 04:32:16
# row6           176  2018-05-01 04:37:05  2018-05-01 04:40:01
#
#       start station id start station name  end station id end station name  \
# row3              3194    McGinley Square            3193     Lincoln Park
# row5              3207        Oakland Ave            3195          Sip Ave
# row6              3194    McGinley Square            3195          Sip Ave
#
#       bikeid                      name_localizedValue    usertype
# row3     100  FREE Bonus Month with Annual Membership  Subscriber
# row5   15271                        Annual Membership  Subscriber
# row6   29298                        Annual Membership  Subscriber

# %%
new_bike_share_data[new_bike_share_data['bikeid']> 30000]
# Out:
#       tripduration            starttime             stoptime  \
# row1           338  2018-05-01 00:04:47  2018-05-01 00:10:25
# row2          1482  2018-05-01 01:31:10  2018-05-01 01:55:53
#
#       start station id start station name  end station id end station name  \
# row1              3639         Harborside            3199     Newport Pkwy
# row2              3681           Grand St            3185        City Hall
#
#       bikeid name_localizedValue    usertype
# row1   33558   Annual Membership  Subscriber
# row2   33593             24 Hour    Customer

# %%
new_bike_share_data.loc[(new_bike_share_data['usertype'] == 'Subscriber') & (new_bike_share_data['bikeid']< 30000) 
                        & (new_bike_share_data['end station name'] == 'Sip Ave')]
# Out:
#       tripduration            starttime             stoptime  \
# row5           303  2018-05-01 04:27:12  2018-05-01 04:32:16
# row6           176  2018-05-01 04:37:05  2018-05-01 04:40:01
#
#       start station id start station name  end station id end station name  \
# row5              3207        Oakland Ave            3195          Sip Ave
# row6              3194    McGinley Square            3195          Sip Ave
#
#       bikeid name_localizedValue    usertype
# row5   15271   Annual Membership  Subscriber
# row6   29298   Annual Membership  Subscriber

# %%
# iloc 
- we can do slicing based on the rows and the columns

syntax - df[row, column]
- only index values is accepted

# %%
new_bike_share_data.iloc[2:: , 2:3:]
# Out:
#                  stoptime
# row3  2018-05-01 01:35:22
# row4  2018-05-01 02:06:40
# row5  2018-05-01 04:32:16
# row6  2018-05-01 04:40:01

# %%
# Normal slicing
- column slicing is not allowed

# loc
- column slicing is possible [only with the column name]

# iloc
- column is possible but with index

# %%
# Creating a new column

new_bike_share_data['Year'] = 2022
# Out:
# C:\Users\MIT\AppData\Local\Temp\ipykernel_2948\3398540627.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_bike_share_data['Year'] = 2022

# %%
new_bike_share_data
# Out:
#       tripduration            starttime             stoptime  \
# row1           338  2018-05-01 00:04:47  2018-05-01 00:10:25
# row2          1482  2018-05-01 01:31:10  2018-05-01 01:55:53
# row3           232  2018-05-01 01:31:29  2018-05-01 01:35:22
# row4           190  2018-05-01 02:03:29  2018-05-01 02:06:40
# row5           303  2018-05-01 04:27:12  2018-05-01 04:32:16
# row6           176  2018-05-01 04:37:05  2018-05-01 04:40:01
#
#       start station id start station name  end station id end station name  \
# row1              3639         Harborside            3199     Newport Pkwy
# row2              3681           Grand St            3185        City Hall
# row3              3194    McGinley Square            3193     Lincoln Park
# row4              3185          City Hall            3186    Grove St PATH
# row5              3207        Oakland Ave            3195          Sip Ave
# row6              3194    McGinley Square            3195          Sip Ave
#
# ...

# %%
new_bike_share_data['Year'] = [2018 , 1019, 2029 , 2234 , 4444 , 1823]
# Out:
# C:\Users\MIT\AppData\Local\Temp\ipykernel_2948\820368212.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_bike_share_data['Year'] = [2018 , 1019, 2029 , 2234 , 4444 , 1823]

# %%
new_bike_share_data
# Out:
#       tripduration            starttime             stoptime  \
# row1           338  2018-05-01 00:04:47  2018-05-01 00:10:25
# row2          1482  2018-05-01 01:31:10  2018-05-01 01:55:53
# row3           232  2018-05-01 01:31:29  2018-05-01 01:35:22
# row4           190  2018-05-01 02:03:29  2018-05-01 02:06:40
# row5           303  2018-05-01 04:27:12  2018-05-01 04:32:16
# row6           176  2018-05-01 04:37:05  2018-05-01 04:40:01
#
#       start station id start station name  end station id end station name  \
# row1              3639         Harborside            3199     Newport Pkwy
# row2              3681           Grand St            3185        City Hall
# row3              3194    McGinley Square            3193     Lincoln Park
# row4              3185          City Hall            3186    Grove St PATH
# row5              3207        Oakland Ave            3195          Sip Ave
# row6              3194    McGinley Square            3195          Sip Ave
#
# ...

# %%
del new_bike_share_data['Year']

# %%
new_bike_share_data
# Out:
#       tripduration            starttime             stoptime  \
# row1           338  2018-05-01 00:04:47  2018-05-01 00:10:25
# row2          1482  2018-05-01 01:31:10  2018-05-01 01:55:53
# row3           232  2018-05-01 01:31:29  2018-05-01 01:35:22
# row4           190  2018-05-01 02:03:29  2018-05-01 02:06:40
# row5           303  2018-05-01 04:27:12  2018-05-01 04:32:16
# row6           176  2018-05-01 04:37:05  2018-05-01 04:40:01
#
#       start station id start station name  end station id end station name  \
# row1              3639         Harborside            3199     Newport Pkwy
# row2              3681           Grand St            3185        City Hall
# row3              3194    McGinley Square            3193     Lincoln Park
# row4              3185          City Hall            3186    Grove St PATH
# row5              3207        Oakland Ave            3195          Sip Ave
# row6              3194    McGinley Square            3195          Sip Ave
#
# ...

# %%
# Year 
# Month 

weather_data
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow
# 3  1/4/2017           24          7   Snow
# 4  1/5/2017           32          4   Rain
# 5  1/6/2017           31          2  Sunny

# %%
# Create 2 new columns Year and Month by extracting the values from day column
# syntax - df['new column'] = df['from existing column'].apply()
